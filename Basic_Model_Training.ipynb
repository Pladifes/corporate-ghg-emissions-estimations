# %% [markdown]
# # Imports

# %%
from functions.production_pipeline import production_pipeline
from functions.apply_model import apply_model_on_forbes_data

# %% [markdown]
# # Model Training

# %%
restricted_features = True
production_pipeline(restricted_features=restricted_features,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23592\2615459670.py in <cell line: 2>()
#       1 restricted_features = True
# ----> 2 production_pipeline(restricted_features=restricted_features)
#
# TypeError: production_pipeline() missing 8 required positional arguments: 'path_rawdata', 'path_models', 'path_benchmark', 'path_results', 'path_plot', 'path_intermediary', 'targets', and 'models'

# %% [markdown]
# # Model application

# %%
save=True
df_forbes_completed=apply_model_on_forbes_data(save=save)

# %%
df_forbes_completed
# Out:
#                                            name                country_hq  \
# 0                                         Apple  United States of America
# 1                                     Microsoft  United States of America
# 2      Saudi Arabian Oil Company (Saudi Aramco)              Saudi Arabia
# 3                                      Alphabet  United States of America
# 4                                        Amazon  United States of America
# ...                                         ...                       ...
# 31955                                 W Holding  United States of America
# 31956                        Cahya Mata Sarawak                  Malaysia
# 31957                                  Tanayong                  Thailand
# 31958                                    Delphi  United States of America
# 31959                    Impac Mortgage Holding  United States of America
#
#             revenue          ebit         asset  fiscal_year  \
# 0      3.851000e+11  9.432000e+10  3.321600e+11         2022
# 1      2.075900e+11  6.902000e+10  3.800900e+11         2022
# 2      5.894700e+11  1.563600e+11  6.538700e+11         2022
# 3      2.828500e+11  5.859000e+10  3.694900e+11         2022
# 4      5.249000e+11  4.290000e+09  4.643800e+11         2022
# ...             ...           ...           ...          ...
# 31955  1.080000e+09  9.000000e+07  1.755000e+10         2007
# 31956  1.750000e+09  0.000000e+00  2.921000e+10         2007
# 31957  2.000000e+07  8.100000e+08  2.100000e+08         2007
# 31958  2.228000e+10 -3.070000e+09  1.367000e+10         2007
# 31959  1.260000e+09 -1.520000e+09  1.941000e+10         2007
#
#                                      gics_sub_ind         cf1_e         cf2_e  \
# 0      Technology Hardware, Storage & Peripherals  1.396575e+07  4.174464e+07
# 1                                Systems Software  9.084710e+06  3.565777e+07
# 2                            Integrated Oil & Gas  1.396575e+07  4.174464e+07
# 3                    Interactive Media & Services  1.396575e+07  4.174464e+07
# 4              Internet & Direct Marketing Retail  1.318028e+07  3.322410e+07
# ...                                           ...           ...           ...
# 31955                    Automobile Manufacturers  1.137009e+05  4.985947e+05
# 31956                      Construction Materials  2.880259e+05  1.128325e+06
# 31957          Diversified Real Estate Activities  1.739028e+04  2.984701e+04
# 31958                      Auto Parts & Equipment  3.256425e+06  5.610412e+06
# 31959                  Thrifts & Mortgage Finance  1.748585e+05  6.427022e+05
#
#               cf3_e       cf123_e  cf1_e + cf2_e + cf3_e
# 0      2.474188e+08  4.531260e+08           7.562552e+08
# 1      2.267253e+08  4.371169e+08           7.085847e+08
# 2      2.143975e+08  4.467148e+08           7.168226e+08
# 3      2.474188e+08  4.598128e+08           7.629420e+08
# 4      1.707880e+08  3.864997e+08           6.036921e+08
# ...             ...           ...                    ...
# 31955  1.351265e+05  1.718057e+06           2.465479e+06
# 31956  1.425419e+05  2.219061e+06           3.777954e+06
# 31957  8.305087e+03  1.338624e+05           1.894048e+05
# 31958  4.423796e+06  3.267220e+07           4.596283e+07
# 31959  1.298516e+05  1.940969e+06           2.888381e+06
#
# [31960 rows x 12 columns]
